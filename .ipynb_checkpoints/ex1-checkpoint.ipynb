# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Import Necessary Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
stroke_filepath = "datasets/healthcare-dataset-stroke-data.csv"

# Read the file into a variable stroke_data
stroke_data = pd.read_csv(stroke_filepath, index_col="id")

# %% [markdown]
# ### Basic Data Exploration

# %%
# Examine the contents of the first 5 rows
stroke_data.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21   NaN     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1

# %%
# Generate summary statistics of the dataframe
stroke_data.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Propotion of Stroke Incidents")

df = stroke_data["stroke"].value_counts()

# Bar chart showing number of people that did not have or did have strokes represented by 0 and 1 respectively.
sns.barplot(x=df.index, y=df.values)
# Out:
# <AxesSubplot:title={'center':'Propotion of Stroke Incidents'}>

# %% [markdown]
# The number of people that did not have stroke is significantly greater than those that had one.

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Gender")


df = stroke_data.groupby(["gender"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["gender"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Gender'}, xlabel='gender', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Relationship Between Age and BMI of Non-Stroke & Stroke Patients")

df = stroke_data.sort_values(by='stroke', ascending=True)
sns.scatterplot(x=df['bmi'], y=df['age'], hue=df['stroke'])
# Out:
# <AxesSubplot:title={'center':'Relationship Between Age and BMI of Non-Stroke & Stroke Patients'}, xlabel='bmi', ylabel='age'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Relationship Between Age and Average Glucose Level of Non-Stroke & Stroke Patients")

df = stroke_data.sort_values(by='stroke', ascending=True)
sns.scatterplot(x=df['avg_glucose_level'], y=df['age'], hue=df['stroke'])
# Out:
# <AxesSubplot:title={'center':'Relationship Between Age and Average Glucose Level of Non-Stroke & Stroke Patients'}, xlabel='avg_glucose_level', ylabel='age'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Relationship Between Average Glucose Level and BMI of Non-Stroke & Stroke Patients")

df = stroke_data.sort_values(by='stroke', ascending=True)
sns.scatterplot(x=df['avg_glucose_level'], y=df['bmi'], hue=df['stroke'])
# Out:
# <AxesSubplot:title={'center':'Relationship Between Average Glucose Level and BMI of Non-Stroke & Stroke Patients'}, xlabel='avg_glucose_level', ylabel='bmi'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Hypertension")


df = stroke_data.groupby(["hypertension"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["hypertension"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Hypertension'}, xlabel='hypertension', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Heart Disease")


df = stroke_data.groupby(["heart_disease"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["heart_disease"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Heart Disease'}, xlabel='heart_disease', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Ever Married")


df = stroke_data.groupby(["ever_married"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["ever_married"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Ever Married'}, xlabel='ever_married', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Work Type")


df = stroke_data.groupby(["work_type"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["work_type"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Work Type'}, xlabel='work_type', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Residence Type")


df = stroke_data.groupby(["Residence_type"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["Residence_type"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Residence Type'}, xlabel='Residence_type', ylabel='percentage of patients having a stroke'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Percentage of Stroke Patients Grouped by Smoking Status")


df = stroke_data.groupby(["smoking_status"]).stroke.agg(lambda df: (len(df.loc[df == 1])/len(df))*100)
df = df.reset_index()
df = df.rename(columns={"stroke":"percentage of patients having a stroke"})

# Grouped bar chart showing number of non-stroke & stroke patients by gender
sns.barplot(x=df["smoking_status"], y=df["percentage of patients having a stroke"])
# Out:
# <AxesSubplot:title={'center':'Percentage of Stroke Patients Grouped by Smoking Status'}, xlabel='smoking_status', ylabel='percentage of patients having a stroke'>
